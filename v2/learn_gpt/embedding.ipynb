# %%
from sentence_transformers import SentenceTransformer
sentences = ["This is an example sentence", "Each sentence is converted"]

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
embeddings = model.encode(sentences)
print(len(embeddings[0]))
print(len(embeddings[1]))
print(embeddings[0])
print(embeddings[1])
# Out:
# 384
# 384
# [ 6.76568896e-02  6.34959042e-02  4.87131365e-02  7.93050155e-02
#   3.74481231e-02  2.65278225e-03  3.93749699e-02 -7.09844381e-03
#   5.93613833e-02  3.15370299e-02  6.00980483e-02 -5.29051982e-02
#   4.06067781e-02 -2.59308536e-02  2.98428312e-02  1.12692942e-03
#   7.35149160e-02 -5.03818542e-02 -1.22386642e-01  2.37028562e-02
#   2.97265705e-02  4.24768366e-02  2.56338250e-02  1.99517747e-03
#  -5.69190718e-02 -2.71598324e-02 -3.29035409e-02  6.60248697e-02
#   1.19007163e-01 -4.58791368e-02 -7.26214722e-02 -3.25840302e-02
#   5.23413345e-02  4.50553037e-02  8.25300161e-03  3.67024019e-02
#  -1.39415637e-02  6.53918609e-02 -2.64271945e-02  2.06408367e-04
#  -1.36643583e-02 -3.62810791e-02 -1.95043981e-02 -2.89738160e-02
#   3.94270346e-02 -8.84090960e-02  2.62423512e-03  1.36714112e-02
#   4.83062677e-02 -3.11565995e-02 -1.17329165e-01 -5.11690788e-02
#  -8.85287747e-02 -2.18962543e-02  1.42986588e-02  4.44167517e-02
# ...

# %%
from gensim.models import Word2Vec
from gensim.test.utils import common_texts
import numpy as np

def l2_distance(vec1, vec2):
    distance = np.linalg.norm(vec1 - vec2)
    return distance

def cosine_similarity(vec1, vec2):
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    similarity = dot_product / (norm_vec1 * norm_vec2)
    return similarity

print(common_texts)

# 训练模型
model = Word2Vec(sentences=common_texts, vector_size=128, window=5, min_count=1, workers=4)

# 查看单词 'computer' 的词向量
cp_vector = model.wv['computer']
m_vector = model.wv['human']
tr_vector = model.wv['trees']
print(len(cp_vector))
print("human and computer: ", cosine_similarity(cp_vector, m_vector), l2_distance(cp_vector, m_vector))
print("trees and computer: ", cosine_similarity(cp_vector, tr_vector), l2_distance(cp_vector, tr_vector))
print("human and trees: ", cosine_similarity(m_vector, tr_vector), l2_distance(m_vector, tr_vector))
# Out:
# [['human', 'interface', 'computer'], ['survey', 'user', 'computer', 'system', 'response', 'time'], ['eps', 'user', 'interface', 'system'], ['system', 'human', 'system', 'eps'], ['user', 'response', 'time'], ['trees'], ['graph', 'trees'], ['graph', 'minors', 'trees'], ['graph', 'minors', 'survey']]
# 128
# human and computer:  -0.02824196 0.07376163
# trees and computer:  0.068104185 0.07011182
# human and trees:  -0.02190189 0.07368577
